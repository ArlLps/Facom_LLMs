# %% [markdown]
# <a href="https://colab.research.google.com/github/ArlLps/Facom_LLMs/blob/main/Aula_3_Transformer_Decoder_only_and_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 3 - Transformer *decoder-only*
#
# Nesta aula você irá modificar o Transformer *decoder-only* fornecido a seguir.
# Observe que em um *decoder-only* não existe:
#
# *   cross-attention
# *   encoder separado
#
# e é utilizado com *auto-regressão*.
#
# ## Objetivo
#
#
# ## Exercício
#
# Neste exercício você deve:
#
# 1.   carregar o seu conjunto de documentos
# 2.   treinar e usar (ou carregar) um tokenizador
# 3.   fazer treino de um modelo decoder-only
# 4.   incluir no loop de treino, inferência usando máxima probabilidade
# 5.   incluir no loop de treino, inferência usando amostragem com temperatura

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %% [markdown]
# # Passo 1: carregar conjunto de documentos

# %%
import json
import re

ds = []
try:
    with open('corpus.jsonl', 'r', encoding='utf-8') as f:
        for line in f:
            data = json.loads(line)
            ds.append(data['text'])

except FileNotFoundError:
    print("ERRO: O arquivo 'corpus.jsonl' não foi encontrado. Gere o dataset primeiro!")

def clean_ascii(text):
    return text

documentos = [clean_ascii(x) for x in ds]
documentos = [t.split(" - ")[0] for t in documentos]
documentos = [t for t in documentos if len(t) > 0]

#documentos = [ "meu doc favorito 1", "meu doc menos favorito 2"]
print("Total documentos:", len(documentos))
print("Sample:", documentos[:10])
# Out:
# Total documentos: 3000
# Sample: ['Se a ilha cruel flutua, então a melancolia cristalina jamais congela galáxia.', 'Nas entranhas de um mistério, o mistério inexorável torna-se harmonia cruel.', 'O tempo amargo colore uma crepúsculo breve nos confins da existência.', 'A cicatriz, que persegue farols, agora desaparece vasta.', 'O suspiro, que molda crepúsculos, agora desperta fugaz.', 'Nas entranhas de um aurora, a sombra profana torna-se deserto antigo.', 'Nas entranhas de um sombra, a doce tempestade torna-se fugaz suspiro.', 'A aurora fria imita uma deserto líquido diante do inevitável.', 'Se o oceano imaculado foge, então o quebrado demônio jamais colore espelho.', 'Nas entranhas de um poesia, o diurno crepúsculo torna-se luminosa ilha.']

# %% [markdown]
# # Passo 2: Carregar ou treinar um tokenizador

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace
import random
import re
import torch # Added torch import

# Defina o seu tokenizador
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
tokenizer.pre_tokenizer = Whitespace()
trainer = BpeTrainer(
    vocab_size=1000, # Aumentando o tamanho do vocabulário para capturar mais subpalavras
    special_tokens=["[PAD]", "[UNK]", "[BOS]", "[EOS]"],
    min_frequency=2 # BPE Trainer often benefits from min_frequency
)
# Treino do tokenizador
tokenizer.train_from_iterator(documentos, trainer)

# Funções auxiliares para transitar entre tokens textuais e ids de tokens
def encode(text):
    ids = tokenizer.encode("[BOS] " + text + " [EOS]").ids
    return torch.tensor(ids, dtype=torch.long)

def decode(ids):
    return tokenizer.decode(ids.tolist())

vocab_size = tokenizer.get_vocab_size()

# %% [markdown]
# ## Definição do modelo Transformer Decoder-only

# %%
class DecoderOnlyTransformer(nn.Module):
    "Implementação de um transformer que tem somente a parte do decoder"
    def __init__(self, vocab_size, d_model=512, n_heads=8, num_layers=6, max_len=64):
        super().__init__()
        self.max_len = max_len

        self.token_emb = nn.Embedding(vocab_size, d_model)
        self.pos_emb = nn.Embedding(max_len, d_model)

        layer = nn.TransformerDecoderLayer(
            d_model=d_model,
            nhead=n_heads,
            dim_feedforward=4 * d_model,
            batch_first=True
        )
        self.decoder = nn.TransformerDecoder(layer, num_layers=num_layers)
        self.lm_head = nn.Linear(d_model, vocab_size)

    def forward(self, x):
        B, T = x.shape
        pos = torch.arange(T, device=x.device).unsqueeze(0)

        h = self.token_emb(x) + self.pos_emb(pos)

        # Máscara causal
        mask = torch.triu(torch.ones(T, T, device=x.device), diagonal=1).bool()

        out = self.decoder(h, h, tgt_mask=mask)
        logits = self.lm_head(out)
        return logits

# %% [markdown]
# # Códigos de inferência

# %% [markdown]
# ## Código de inferência simples: token com maior probabilidade

# %%
def max_prob_sampling(logits):
    next_token = logits.argmax(dim=-1)
    return next_token.unsqueeze(0)

# %% [markdown]
# ## Código de inferência avançada: amostragem com temperatura

# %%
import torch

# Inferência (com temperature e top_p)
def sampling(logits, top_p=0.9, top_k=None, temperature=1.0):
    # Ajusta pela temperatura
    logits = logits / temperature

    # Se top_k for especificado, filtra por top_k primeiro
    if top_k is not None:
        # Ensure top_k is not larger than the vocabulary size
        k_to_use = min(top_k, logits.size(-1))
        # Get the top_k values and indices
        v, _ = torch.topk(logits, k_to_use)
        # Set logits of all values smaller than the k-th value to -inf
        logits[logits < v[:, [-1]]] = float('-inf')

    # Ordena os logits
    sorted_logits, sorted_indices = torch.sort(logits, descending=True)
    cumulative_probs = torch.softmax(sorted_logits, dim=-1).cumsum(dim=-1)

    # Mascara tokens acima do top_p
    mask = cumulative_probs > top_p
    # Garante que ao menos um token permaneça
    mask[..., 1:] = mask[..., :-1].clone()
    mask[..., 0] = False

    filtered_logits = sorted_logits.masked_fill(mask, float('-inf'))
    probs = torch.softmax(filtered_logits, dim=-1)

    # Amostra o token
    sampled_idx = torch.multinomial(probs, num_samples=1)

    # Converte para índice na tabela original
    next_token = sorted_indices[sampled_idx]

    return next_token


def decode(ids):
    if isinstance(ids, torch.Tensor):
        ids = ids.tolist()
    return tokenizer.decode(ids, skip_special_tokens=True)


def generate(prompt, next_token_function, max_new_tokens=5, top_k=None, top_p=0.9, temperature=1.0):
    model.eval()
    x = encode(prompt).unsqueeze(0).to(device)

    for _ in range(max_new_tokens):
        logits = model(x)[:, -1, :]  # pega apenas o último passo

        # Passa os parâmetros de amostragem se a função for top_p_sampling
        if next_token_function == sampling:
            next_token = next_token_function(logits.squeeze(0), top_k=top_k, top_p=top_p, temperature=temperature)
        else:
            next_token = next_token_function(logits.squeeze(0))

        x = torch.cat([x, next_token.unsqueeze(0)], dim=1)

        if next_token.item() == tokenizer.token_to_id("[EOS]"):
            break

    return decode(x[0])

# %% [markdown]
# # 4. Fazer treino de modelo: códigos de treino

# %%
# Função auxiliar para gerar batches de exemplos para treino
def sample_batch(batch_size=16, max_len=20):
    batch = random.sample(documentos, batch_size)
    tokenized = [encode(t) for t in batch]

    max_t = min(max(len(x) for x in tokenized), max_len)
    padded = []

    for x in tokenized:
        x = x[:max_t]
        pad_len = max_t - len(x)
        if pad_len > 0:
            x = torch.cat([x, torch.zeros(pad_len, dtype=torch.long)])
        padded.append(x)

    return torch.stack(padded)

################################
device = "cuda" if torch.cuda.is_available() else "cpu"
model = DecoderOnlyTransformer(vocab_size).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
#################################

steps = 100000

for step in range(1, steps + 1):
    model.train()
    batch = sample_batch().to(device)

    logits = model(batch[:, :-1])
    loss = F.cross_entropy(
        logits.reshape(-1, vocab_size),
        batch[:, 1:].reshape(-1),
        ignore_index=tokenizer.token_to_id("[PAD]")
    )

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if step % 50 == 0:
        ppl = torch.exp(loss).item()
        print(f"[step {step}] loss={loss.item():.4f}, ppl={ppl:.2f}")

    if step % 100 == 0:
        print("Generated text:")
        print(generate("Se o oceano imaculado foge,", next_token_function=sampling))
        print("--------------------------------------")

print("Training completed.")
# Out:
# [step 50] loss=5.1481, ppl=172.11
# [step 100] loss=4.2020, ppl=66.82
# Generated text:
# Se o oceano imaculado foge , u vazia suspiros luminosa gélida
# --------------------------------------
# [step 150] loss=3.7908, ppl=44.29
# [step 200] loss=3.5257, ppl=33.98
# Generated text:
# Se o oceano imaculado foge , respostas cicatriz deuses .
# --------------------------------------
# [step 250] loss=3.0388, ppl=20.88
# [step 300] loss=3.2074, ppl=24.71
# Generated text:
# Se o oceano imaculado foge , a diante tro jamais vasto
# --------------------------------------
# [step 350] loss=2.7403, ppl=15.49
# [step 400] loss=2.7975, ppl=16.40
# Generated text:
# Se o oceano imaculado foge , sereno estátua imaculada jamais vidro
# --------------------------------------
# [step 450] loss=3.0453, ppl=21.02
# [step 500] loss=2.4858, ppl=12.01
# Generated text:
# Se o oceano imaculado foge , efêmero profundo retorna último relógios
# --------------------------------------
# [step 550] loss=2.3083, ppl=10.06
# [step 600] loss=2.5851, ppl=13.26
# Generated text:
# Se o oceano imaculado foge , o , sas ruína .
# --------------------------------------
# [step 650] loss=2.4803, ppl=11.94
# [step 700] loss=2.2862, ppl=9.84
# Generated text:
# Se o oceano imaculado foge , o ardente instante respostas catedral
# --------------------------------------
# [step 750] loss=2.3108, ppl=10.08
# [step 800] loss=2.1800, ppl=8.85
# Generated text:
# Se o oceano imaculado foge , fugaz oceano crepúsculo ilumina la
# --------------------------------------
# [step 850] loss=2.1356, ppl=8.46
# [step 900] loss=2.1491, ppl=8.58
# Generated text:
# Se o oceano imaculado foge , petrificado profundo labirinto paradox jardim
# --------------------------------------
# [step 950] loss=1.9478, ppl=7.01
# [step 1000] loss=1.9957, ppl=7.36
# Generated text:
# Se o oceano imaculado foge , o solitário êxtases acaricia enquanto
# --------------------------------------
# [step 1050] loss=1.8068, ppl=6.09
# [step 1100] loss=1.7586, ppl=5.80
# Generated text:
# Se o oceano imaculado foge , o suspiro ascende
# --------------------------------------
# [step 1150] loss=1.5369, ppl=4.65
# [step 1200] loss=1.5776, ppl=4.84
# Generated text:
# Se o oceano imaculado foge , gn farol destinos - lda
# --------------------------------------
# [step 1250] loss=1.4855, ppl=4.42
# [step 1300] loss=1.2461, ppl=3.48
# Generated text:
# Se o oceano imaculado foge , o paradoxo abraça visível desperta
# --------------------------------------
# [step 1350] loss=1.1226, ppl=3.07
# [step 1400] loss=0.9216, ppl=2.51
# Generated text:
# Se o oceano imaculado foge , o águas profano nias profano
# --------------------------------------
# [step 1450] loss=0.8685, ppl=2.38
# [step 1500] loss=0.7907, ppl=2.20
# Generated text:
# Se o oceano imaculado foge , o paradoxo renasce último assiste
# --------------------------------------
# [step 1550] loss=0.6933, ppl=2.00
# [step 1600] loss=0.5330, ppl=1.70
# Generated text:
# Se o oceano imaculado foge , o demônio demônio vene harmonias
# --------------------------------------
# [step 1650] loss=0.5091, ppl=1.66
# [step 1700] loss=0.4301, ppl=1.54
# Generated text:
# Se o oceano imaculado foge , imaculado caos dorme .
# --------------------------------------
# [step 1750] loss=0.3737, ppl=1.45
# [step 1800] loss=0.3071, ppl=1.36
# Generated text:
# Se o oceano imaculado foge , Nas vazio punhal e o
# --------------------------------------
# [step 1850] loss=0.2588, ppl=1.30
# [step 1900] loss=0.2715, ppl=1.31
# Generated text:
# Se o oceano imaculado foge , o trêmulo nebuloso sagrado mil
# --------------------------------------
# [step 1950] loss=0.2505, ppl=1.28
# [step 2000] loss=0.1933, ppl=1.21
# Generated text:
# Se o oceano imaculado foge , pia enquanto x ldi confins
# --------------------------------------
# [step 2050] loss=0.1860, ppl=1.20
# [step 2100] loss=0.1910, ppl=1.21
# Generated text:
# Se o oceano imaculado foge , agora cul gélida jamais es
# --------------------------------------
# [step 2150] loss=0.2123, ppl=1.24
# [step 2200] loss=0.1782, ppl=1.20
# Generated text:
# Se o oceano imaculado foge , mil utopia imaculada gu .
# --------------------------------------
# [step 2250] loss=0.1367, ppl=1.15
# [step 2300] loss=0.1765, ppl=1.19
# Generated text:
# Se o oceano imaculado foge , farols cristal fosse jamais madru
# --------------------------------------
# [step 2350] loss=0.0959, ppl=1.10
# [step 2400] loss=0.1305, ppl=1.14
# Generated text:
# Se o oceano imaculado foge , invade diurno dorme desperta devora
# --------------------------------------
# [step 2450] loss=0.0990, ppl=1.10
# [step 2500] loss=0.1104, ppl=1.12
# Generated text:
# Se o oceano imaculado foge , melancólica melancólica melancólica profundo do
# --------------------------------------
# [step 2550] loss=0.0846, ppl=1.09
# [step 2600] loss=0.0818, ppl=1.09
# Generated text:
# Se o oceano imaculado foge , silên galáx sur res
# --------------------------------------
# [step 2650] loss=0.0761, ppl=1.08
# [step 2700] loss=0.0692, ppl=1.07
# Generated text:
# Se o oceano imaculado foge , dos venera ressuscita ruge ressuscita
# --------------------------------------
# [step 2750] loss=0.0498, ppl=1.05
# [step 2800] loss=0.0589, ppl=1.06
# Generated text:
# Se o oceano imaculado foge , galáx etérea sóis cristalino .
# --------------------------------------
# [step 2850] loss=0.1047, ppl=1.11
# [step 2900] loss=0.0556, ppl=1.06
# Generated text:
# Se o oceano imaculado foge , oni jardim ruína eternidade ando
# --------------------------------------
# [step 2950] loss=0.0675, ppl=1.07
# [step 3000] loss=0.0820, ppl=1.09
# Generated text:
# Se o oceano imaculado foge , o catedrals ascende jamais mas
# --------------------------------------
# [step 3050] loss=0.0535, ppl=1.05
# [step 3100] loss=0.0401, ppl=1.04
# Generated text:
# Se o oceano imaculado foge , crepúsculo tro diurna sombrio .
# --------------------------------------
# [step 3150] loss=0.0591, ppl=1.06
# [step 3200] loss=0.0470, ppl=1.05
# Generated text:
# Se o oceano imaculado foge , etérea foge o turvas o
# --------------------------------------
# [step 3250] loss=0.0486, ppl=1.05
# [step 3300] loss=0.0355, ppl=1.04
# Generated text:
# Se o oceano imaculado foge , persiste pe infinita
# --------------------------------------
# [step 3350] loss=0.0351, ppl=1.04
# [step 3400] loss=0.0515, ppl=1.05
# Generated text:
# Se o oceano imaculado foge , jardim jardim jardim jardim jardim
# --------------------------------------
# [step 3450] loss=0.0363, ppl=1.04
# [step 3500] loss=0.0391, ppl=1.04
# Generated text:
# Se o oceano imaculado foge , então etéreo etéreo .
# --------------------------------------
# [step 3550] loss=0.0309, ppl=1.03
# [step 3600] loss=0.0239, ppl=1.02
# Generated text:
# Se o oceano imaculado foge , sem quebrado o oceano o
# --------------------------------------
# [step 3650] loss=0.0366, ppl=1.04
# [step 3700] loss=0.0349, ppl=1.04
# Generated text:
# Se o oceano imaculado foge , noturno espelhos eternidade almas luminoso
# --------------------------------------
# [step 3750] loss=0.0332, ppl=1.03
# [step 3800] loss=0.0254, ppl=1.03
# Generated text:
# Se o oceano imaculado foge , di cristalino cristalino consome noite
# --------------------------------------
# [step 3850] loss=0.0304, ppl=1.03
# [step 3900] loss=0.0314, ppl=1.03
# Generated text:
# Se o oceano imaculado foge , na surdo í existência .
# --------------------------------------
# [step 3950] loss=0.0226, ppl=1.02
# [step 4000] loss=0.0357, ppl=1.04
# Generated text:
# Se o oceano imaculado foge , invade jamais velas jamais deuses
# --------------------------------------
# [step 4050] loss=0.0232, ppl=1.02
# [step 4100] loss=0.0288, ppl=1.03
# Generated text:
# Se o oceano imaculado foge , espectros chora do crepúsculo agoniza
# --------------------------------------
# [step 4150] loss=0.0178, ppl=1.02
# [step 4200] loss=0.0199, ppl=1.02
# Generated text:
# Se o oceano imaculado foge , foge foge ascende devora desaparece
# --------------------------------------
# [step 4250] loss=0.0175, ppl=1.02
# [step 4300] loss=0.0176, ppl=1.02
# Generated text:
# Se o oceano imaculado foge , lágrima oceano montanha .
# --------------------------------------
# [step 4350] loss=0.0169, ppl=1.02
# [step 4400] loss=0.0143, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , sombrio noturno a contra a
# --------------------------------------
# [step 4450] loss=0.0167, ppl=1.02
# [step 4500] loss=0.0146, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , qual quimeras para trás .
# --------------------------------------
# [step 4550] loss=0.0151, ppl=1.02
# [step 4600] loss=0.0133, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , o relógios deser promessas o
# --------------------------------------
# [step 4650] loss=0.0117, ppl=1.01
# [step 4700] loss=0.0116, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , face espectro profundezas - se
# --------------------------------------
# [step 4750] loss=0.0131, ppl=1.01
# [step 4800] loss=0.0147, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , tempestade tempestade tempestade tempestade ventos
# --------------------------------------
# [step 4850] loss=0.0112, ppl=1.01
# [step 4900] loss=0.0119, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , na punhal vi último do
# --------------------------------------
# [step 4950] loss=0.0112, ppl=1.01
# [step 5000] loss=0.0133, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , profundo profundo profundo profundo profundo
# --------------------------------------
# [step 5050] loss=0.0131, ppl=1.01
# [step 5100] loss=0.0109, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , poesia tempestade ilha vaz .
# --------------------------------------
# [step 5150] loss=0.0089, ppl=1.01
# [step 5200] loss=0.0094, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , arde foge o arde arde
# --------------------------------------
# [step 5250] loss=0.0082, ppl=1.01
# [step 5300] loss=0.0090, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , agora ve angústia .
# --------------------------------------
# [step 5350] loss=0.0088, ppl=1.01
# [step 5400] loss=0.0080, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , o melancolia cristalino jamais jamais
# --------------------------------------
# [step 5450] loss=0.0081, ppl=1.01
# [step 5500] loss=0.0073, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , crepúsculo máscara máscara na .
# --------------------------------------
# [step 5550] loss=0.0084, ppl=1.01
# [step 5600] loss=0.0066, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , foge oceano oceano oceano oceano
# --------------------------------------
# [step 5650] loss=0.0076, ppl=1.01
# [step 5700] loss=0.0060, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , consome mistério fin o buscando
# --------------------------------------
# [step 5750] loss=0.0069, ppl=1.01
# [step 5800] loss=0.0066, ppl=1.01
# Generated text:
# Se o oceano imaculado foge , foge foge montanha jamais jamais
# --------------------------------------
# [step 5850] loss=0.0062, ppl=1.01

# %% [markdown]
# # Exercício: controle de temperatura, Top-K e Top-P
#
# Modifique o código a seguir para fazer a visualização de produção de tokens do modelo que você treinou.

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, Markdown

# -----------------------------
# Mock language-model logits
# -----------------------------
TOKENS = ["blue", "purple", "violet", "vio", "not", "Blue", "green", "gray", "grey", "black"]
BASE_LOGITS = np.array([6.0, 1.5, 0.5, 0.2, 0.2, 0.0, -5.0, -5.0, -5.0, -5.0])

def softmax(x):
    e = np.exp(x - np.max(x))
    return e / e.sum()

def apply_temperature(logits, temperature):
    return logits / max(temperature, 1e-5)

def apply_top_k(probs, k):
    if k >= len(probs):
        return probs
    idx = np.argsort(probs)[::-1]
    mask = np.zeros_like(probs)
    mask[idx[:k]] = 1
    probs = probs * mask
    return probs / probs.sum()

def apply_top_p(probs, p):
    idx = np.argsort(probs)[::-1]
    cumulative = np.cumsum(probs[idx])
    mask = cumulative <= p
    mask[np.argmax(mask)] = True
    new_probs = np.zeros_like(probs)
    new_probs[idx[mask]] = probs[idx[mask]]
    return new_probs / new_probs.sum()

# -----------------------------
# Widgets
# -----------------------------
prompt_dropdown = widgets.Dropdown(
    options=["Roses are red, violets are..."],
    value="Roses are red, violets are...",
    description="Prompt",
    layout=widgets.Layout(width="95%")
)

temperature_slider = widgets.FloatSlider(
    value=1.0, min=0.1, max=5.0, step=0.1,
    description="Temperatura",
    readout_format=".1f",
    layout=widgets.Layout(width="90%")
)

topk_slider = widgets.IntSlider(
    value=6, min=1, max=10, step=1,
    description="Top-K",
    layout=widgets.Layout(width="90%")
)

topp_slider = widgets.FloatSlider(
    value=1.0, min=0.1, max=1.0, step=0.05,
    description="Top-P",
    readout_format=".2f",
    layout=widgets.Layout(width="90%")
)

# -----------------------------
# Plot
# -----------------------------
output_plot = widgets.Output()

def update_plot(*args):
    with output_plot:
        output_plot.clear_output()

        logits = apply_temperature(BASE_LOGITS, temperature_slider.value)
        probs = softmax(logits)
        probs = apply_top_k(probs, topk_slider.value)
        probs = apply_top_p(probs, topp_slider.value)

        fig, ax = plt.subplots(figsize=(10, 4))
        bars = ax.bar(TOKENS, probs * 100)
        ax.set_ylim(0, 100)
        ax.set_ylabel("Probabilidade (%)")
        ax.set_title("Probabilidade do próximo token")

        for bar, p in zip(bars, probs):
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height(),
                f"{p*100:.2f}%",
                ha="center",
                va="bottom",
                fontsize=9
            )

        plt.xticks(rotation=0)
        plt.show()

for w in [temperature_slider, topk_slider, topp_slider]:
    w.observe(update_plot, names="value")

# -----------------------------
# Collapsible explanation
# -----------------------------
accordion = widgets.Accordion(
    children=[widgets.HTML(
        """
        <ul>
          <li><b>Temperatura</b>: Controla aleatoriedade com mudança na escala dos logits.</li>
          <li><b>Top-K</b>: Restringe a amostra aos K tokens mais prováveis.</li>
          <li><b>Top-P</b>: Usa somente os menor conjunto de tokens que resultam em probabilidade acumulada até P.</li>
        </ul>
        """
    )]
)
accordion.set_title(0, "Entenda a visualização")

# -----------------------------
# Layout
# -----------------------------
controls = widgets.VBox([
    prompt_dropdown,
    widgets.HBox([temperature_slider]),
    widgets.HBox([topk_slider]),
    widgets.HBox([topp_slider])
])

display(Markdown("## Visualização de controle de Temperatura, Top-K e Top-P."))
display(widgets.VBox([
    widgets.HTML("<b>Parameters</b>"),
    controls,
    output_plot,
    accordion
]))

update_plot()
